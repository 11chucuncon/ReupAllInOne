# %% [markdown]
# # Chạy backend trên Google Colab
#
# Notebook này chuẩn bị môi trường, clone repository, mount Google Drive và chạy Gradio UI với `share=True`.
# Nhấn `Runtime -> Run all` hoặc lần lượt chạy các cell để khởi động.

# %%
# Cài đặt các package cần thiết trên Colab
# !pip install -q gradio PyYAML yt-dlp

# %%
# Clone repository nếu chưa có
import os
repo_path = '/content/project'
if not os.path.exists(repo_path):
    # !git clone --depth 1 --branch master https://github.com/hanhwannau/A.git {repo_path} || git clone --depth 1 --branch main https://github.com/hanhwannau/A.git {repo_path}
print('Repo path:', repo_path)
print('Contents:')
# !ls -la {repo_path}

# %%
# Mount Google Drive để lưu output và log nếu muốn
from google.colab import drive
drive.mount('/content/drive', force_remount=False)

# %%
# Chạy Gradio UI từ repository
import os, sys
repo_path = '/content/project'
os.chdir(repo_path)
sys.path.insert(0, repo_path)
# !python colab_gradio_ui.py
